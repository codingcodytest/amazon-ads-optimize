# %%
# !pip install --upgrade pip
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 58.5 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.1.2
#     Uninstalling pip-22.1.2:
#       Successfully uninstalled pip-22.1.2
# ...

# %% [markdown]
# ## Set Up

# %%
import io
import re
import os
import boto3
import sagemaker
import sys

# !{sys.executable} -m pip install sagemaker pandas numpy --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 567.9/567.9 kB 53.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sagemaker: filename=sagemaker-2.105.0-py2.py3-none-any.whl size=783588 sha256=2ac394e097bd186a203e491e7b75ace95ce49f1bdeb290113ceb0d39324732a7
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/5a/08/62/64b429d14fdaa6e6965aeaf2667289c2aab71c95d39e432299
# Successfully built sagemaker
# ...
#   Attempting uninstall: sagemaker
#     Found existing installation: sagemaker 2.103.0
#     Uninstalling sagemaker-2.103.0:
#       Successfully uninstalled sagemaker-2.103.0
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import json
from IPython.display import display
from time import strftime, gmtime
from sagemaker.inputs import TrainingInput
from sagemaker.serializers import CSVSerializer

# %%
# Define session and bucket
sess = sagemaker.Session()
bucket = sess.default_bucket()
prefix = "sagemaker/xgboost-ads"

# Define IAM role
from sagemaker import get_execution_role

role = get_execution_role()

# %% [markdown]
# ## Data

# %%
#sample code for download opendata from s3 open bucket
'''
s3 = boto3.client("s3")
s3.download_file(f"sagemaker-sample-files", "datasets/tabular/synthetic/churn.txt", "churn.txt")
churn = pd.read_csv("./xx.csv")
pd.set_option("display.max_columns", 500)
churn
len(churn.columns)
'''
# Out:
# '\ns3 = boto3.client("s3")\ns3.download_file(f"sagemaker-sample-files", "datasets/tabular/synthetic/churn.txt", "churn.txt")\nchurn = pd.read_csv("./xx.csv")\npd.set_option("display.max_columns", 500)\nchurn\nlen(churn.columns)\n'

# %%
# load local data 
data =pd.read_pickle("./data_final.pkl")
data
# Out:
#        clicks  cpc_fee  total_order  Lag_1_clicks  rolling_mean_1_clicks  \
# 0          11     0.58            0           NaN                   11.0
# 1           9     0.60            0           NaN                    9.0
# 2          10     0.57            0           NaN                   10.0
# 3          11     0.53            0           NaN                   11.0
# 4           8     0.55            0           NaN                    8.0
# ...       ...      ...          ...           ...                    ...
# 13769       1     0.73            0           NaN                    1.0
# 13770       1     0.78            0           NaN                    1.0
# 13771       1     1.14            0           NaN                    1.0
# 13772       1     1.60            0           NaN                    1.0
# 13773       1     1.30            0           NaN                    1.0
#
#        rolling_sum_3_clicks  Lag_3_clicks  rolling_mean_3_clicks  \
# ...

# %%
# data.columns.tolist()

# %% [markdown]
# ### Data exploring

# %%
# Frequency tables for each categorical feature
for column in data.select_dtypes(include=["object"]).columns:
    display(pd.crosstab(index=churn[column], columns="% observations", normalize="columns"))
    
    
# Histograms for each numeric features
display(data.describe())
# %matplotlib inline
#hist = data.hist(bins=30, sharey=True, figsize=(1000, 1000))
# Out:
#              clicks       cpc_fee   total_order  Lag_1_clicks  \
# count  13774.000000  13774.000000  13774.000000           0.0
# mean       4.985262      1.016764      0.355888           NaN
# std        9.937911      0.517731      0.952416           NaN
# min        1.000000      0.030000      0.000000           NaN
# 25%        1.000000      0.600000      0.000000           NaN
# 50%        2.000000      0.910000      0.000000           NaN
# 75%        5.000000      1.380000      0.000000           NaN
# max      168.000000      4.480000     18.000000           NaN
#
#        rolling_mean_1_clicks  rolling_sum_3_clicks  Lag_3_clicks  \
# count           13774.000000                   0.0           0.0
# mean                4.985262                   NaN           NaN
# std                 9.937911                   NaN           NaN
# min                 1.000000                   NaN           NaN
# 25%                 1.000000                   NaN           NaN
# ...

# %%
data.dtypes
# Out:
# clicks                     int64
# cpc_fee                  float64
# total_order                int64
# Lag_1_clicks             float64
# rolling_mean_1_clicks    float64
#                           ...
# values_765               float32
# values_766               float32
# values_767               float32
# quater_2                   uint8
# quater_3                   uint8
# Length: 797, dtype: object

# %%
#split data to train and test dataset
from sklearn.model_selection import train_test_split

X = data.drop('total_order', axis=1).fillna(0)
y = data['total_order'].fillna(0)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)


'''
train_data, validation_data, test_data = np.split(
    dataset.sample(frac=1, random_state=1729),
    [int(0.7 * len(dataset)), int(0.9 * len(dataset))],
)
'''

# %% [markdown]
# Amazon SageMaker XGBoost can train on data in either a CSV or LibSVM format. For this example, we'll stick with CSV. It should:
# - Have the predictor variable in the first column
# - Not have a header row

# %%
train_data = pd.concat([y_train, X_train], axis=1)
train_data.head(4)
# Out:
#       total_order  clicks  cpc_fee  Lag_1_clicks  rolling_mean_1_clicks  \
# 309             0      11     0.24           0.0                   11.0
# 785             0       7     0.64           0.0                    7.0
# 6828            1       6     0.51           0.0                    6.0
# 7921            0       1     1.82           0.0                    1.0
#
#       rolling_sum_3_clicks  Lag_3_clicks  rolling_mean_3_clicks  \
# 309                    0.0           0.0                    0.0
# 785                    0.0           0.0                    0.0
# 6828                   0.0           0.0                    0.0
# 7921                   0.0           0.0                    0.0
#
#       rolling_sum_7_clicks  Lag_7_clicks  ...  values_760  values_761  \
# 309                    0.0           0.0  ...    0.356615   -0.017270
# 785                    0.0           0.0  ...    0.211368   -0.073111
# ...

# %%
test_data = pd.concat([y_test, X_test], axis=1)
test_data.head(4)
# Out:
#       total_order  clicks  cpc_fee  Lag_1_clicks  rolling_mean_1_clicks  \
# 1238            0       3     0.88           0.0                    3.0
# 3093            0       2     0.25           0.0                    2.0
# 5619            0       2     0.49           0.0                    2.0
# 221             0       5     0.52           0.0                    5.0
#
#       rolling_sum_3_clicks  Lag_3_clicks  rolling_mean_3_clicks  \
# 1238                   0.0           0.0                    0.0
# 3093                   0.0           0.0                    0.0
# 5619                   0.0           0.0                    0.0
# 221                    0.0           0.0                    0.0
#
#       rolling_sum_7_clicks  Lag_7_clicks  ...  values_760  values_761  \
# 1238                   0.0           0.0  ...    0.147650    0.212327
# 3093                   0.0           0.0  ...    0.302976    0.318188
# ...

# %%
train_data.to_csv("train.csv", header=False, index=False)
test_data.to_csv("validation.csv", header=False, index=False)

# %%
#upload train data to your own bucket
'''
boto3.Session().resource("s3").Bucket(bucket).Object(
    os.path.join(prefix, "train/train.csv")
).upload_file("train.csv")
boto3.Session().resource("s3").Bucket(bucket).Object(
    os.path.join(prefix, "validation/validation.csv")
).upload_file("validation.csv")
'''
region = boto3.session.Session().region_name

s3_client = boto3.client('s3', region_name=region)

s3_client.upload_file('train.csv', bucket, prefix + '/train.csv')

training_data_uri = 's3://{}/{}/train.csv'.format(bucket,prefix)
print(training_data_uri)
# Out:
# s3://sagemaker-ap-northeast-1-249517808360/sagemaker/xgboost-ads/train.csv

# %%
s3_client.upload_file('validation.csv', bucket, prefix + '/validation.csv')
test_data_uri = 's3://{}/{}/validation.csv'.format(bucket,prefix)

# %%
print(test_data_uri)
# Out:
# s3://sagemaker-ap-northeast-1-249517808360/sagemaker/xgboost-ads/validation.csv

# %%
training_data_uri = 's3://{}/{}/train.csv'.format(bucket,prefix)
test_data_uri = 's3://{}/{}/validation.csv'.format(bucket,prefix)

# %% [markdown]
# ### Train
# Moving onto training, first we'll need to specify the locations of the XGBoost algorithm containers.

# %%
container = sagemaker.image_uris.retrieve("xgboost", sess.boto_region_name, "1.5-1")
display(container)
# Out:
# '354813040037.dkr.ecr.ap-northeast-1.amazonaws.com/sagemaker-xgboost:1.5-1'

# %%
s3_input_train = TrainingInput(
    training_data_uri, content_type="csv"
)
s3_input_validation = TrainingInput(
    test_data_uri, content_type="csv"
)

# %%
sess = sagemaker.Session()

xgb = sagemaker.estimator.Estimator(
    container,
    role,
    instance_count=1,
    instance_type="ml.m4.xlarge",
    output_path="s3://{}/{}/output".format(bucket, prefix),
    sagemaker_session=sess,
)
xgb.set_hyperparameters(
    max_depth=6,
    eta=0.2,
    gamma=4,
    min_child_weight=7.5,
    subsample=0.8,
    verbosity=0,
    objective="reg:squaredlogerror",
    num_round=100,
)

xgb.fit({"train": s3_input_train, "validation": s3_input_validation})
# Out:
# 2022-08-15 15:11:31 Starting - Starting the training job...
# 2022-08-15 15:11:57 Starting - Preparing the instances for trainingProfilerReport-1660576291: InProgress
# ............
# 2022-08-15 15:13:56 Downloading - Downloading input data...
# 2022-08-15 15:14:16 Training - Downloading the training image......
# 2022-08-15 15:15:17 Training - Training image download completed. Training in progress.[2022-08-15 15:15:21.654 ip-10-0-200-240.ap-northeast-1.compute.internal:1 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-08-15:15:15:21:INFO] Imported framework sagemaker_xgboost_container.training
# [2022-08-15:15:15:21:INFO] Failed to parse hyperparameter objective value reg:squaredlogerror to Json.
# Returning the value itself
# [2022-08-15:15:15:21:INFO] No GPUs detected (normal if no gpus installed)
# [2022-08-15:15:15:21:INFO] Running XGBoost Sagemaker in algorithm mode
# [2022-08-15:15:15:21:INFO] Determined delimiter of CSV input is ','
# ...

# %%
'''
XGBRegressor(
            max_depth=6,
            n_estimators=500,
            min_child_weight=7.5,
            learning_rate=0.03,
            nthread=8,
            subsample=0.80,
            colsample_bytree=0.80)
            
'''

# %% [markdown]
# ## host

# %%
'''
xgb_predictor = xgb.deploy(
    initial_instance_count=1, instance_type="ml.m4.xlarge", serializer=CSVSerializer()
)
'''

# %%
from sagemaker.model import Model

container = sagemaker.image_uris.retrieve("xgboost", sess.boto_region_name, "1.5-1")

xgb = Model(image_uri=container, 
            model_data='s3://sagemaker-ap-northeast-1-249517808360/sagemaker/xgboost-ads/output/sagemaker-xgboost-2022-08-15-15-11-31-423/output/model.tar.gz', 
            role=role)
'''
model = PyTorchModel(model_data='s3://{}/{}/output/model-pytorch.tar.gz'.format(bucket, training_job_name), role=role,
                             entry_point='inference.py', framework_version='1.8.1', py_version='py3')  # TODO set model_server_workers=1 to avoid torchhub bug, model_server_workers=1
        
'''                                                        
# predictor = estimator.deploy(initial_instance_count=1, instance_type=instance_type)                         
xgb_predictor = xgb.deploy(
    initial_instance_count=1, instance_type="ml.m4.xlarge", serializer=CSVSerializer()
)
# Out:
# '354813040037.dkr.ecr.ap-northeast-1.amazonaws.com/sagemaker-xgboost:1.5-1'
# ------!

# %% [markdown]
# ## Evaluate
# Now that we have a hosted endpoint running, we can make real-time predictions from our model very easily, simply by making a http POST request. But first, we'll need to set up serializers and deserializers for passing our test_data NumPy arrays to the model behind the endpoint.

# %%
import sagemaker
import boto3
# Define session and bucket
sess = sagemaker.Session()
bucket = sess.default_bucket()
prefix = "sagemaker/xgboost-ads"

# Define IAM role
from sagemaker import get_execution_role
role = get_execution_role()

# Define region
session = boto3.Session()
region=session.region_name

s3 = boto3.client("s3")
s3.download_file(f"sagemaker-ap-northeast-1-249517808360","sagemaker/xgboost-ads/validation.csv", "ads_test.csv")

# %%
import pandas as pd
data =pd.read_pickle("./data_final.pkl")
df = data.tail(20).fillna(0)
df = df.drop("total_order",axis=1)

# %%
df.to_csv("test.csv", header=False, index=False)

# %%
import pandas as pd
daf = pd.read_csv("test.csv")
testda = daf.head(10)
data = testda.values

# %%
# %time
from sagemaker.xgboost.model import XGBoostPredictor
from sagemaker.serializers import CSVSerializer
    
predictor = XGBoostPredictor(endpoint_name='sagemaker-xgboost-2022-08-19-08-50-05-643',serializer=CSVSerializer())
response = predictor.predict(data)
response
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
# [['0.0053924741223454475'],
#  ['0.0053924741223454475'],
#  ['0.0053924741223454475'],
#  ['0.0053924741223454475'],
#  ['0.0053924741223454475'],
#  ['0.0053924741223454475'],
#  ['0.0053924741223454475'],
#  ['0.0053924741223454475'],
#  ['0.0053924741223454475'],
#  ['0.0053924741223454475']]

# %%
'''
predictor = sagemaker.predictor.Predictor(endpoint_name,                                         
                                          serializer=CSVSerializer(),
                                          ContentType = 'text/csv')
'''
